# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

df = pd.read_csv('../data/telecom_churn.csv')
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# Fill NaN only in numeric columns
numeric_cols = df.select_dtypes(include=['number']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())
if 'customerID' in df.columns:
	df.drop(['customerID'], axis=1, inplace=True)
df = pd.get_dummies(df, drop_first=True)
df.to_csv('../data/cleaned_telecom_churn.csv', index=False)
df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              0       1           29.85         29.85        False
# 1              1      34           56.95       1889.50         True
# 2              0       2           53.85        108.15         True
# 3              0      45           42.30       1840.75        False
# 4              1       5           70.70        353.70        False
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
# 1        False           False              True
# 2        False           False              True
# 3         True            True             False
# 4        False           False              True
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  TechSupport_Yes  \
# 0                            True              False  ...            False
# 1                           False              False  ...            False
# 2                           False               True  ...             True
# 3                            True              False  ...            False
# 4                           False               True  ...            False
#
#    StreamingTV_Yes  StreamingMovies_Yes  Contract_One year  Contract_Two year  \
# 0            False                False              False              False
# 1             True                 True              False               True
# 2             True                 True              False              False
# 3            False                False               True              False
# 4             True                False              False              False
#
#    PaperlessBilling_Yes  PaymentMethod_Credit card (automatic)  \
# 0                  True                                  False
# 1                 False                                  False
# 2                  True                                  False
# 3                 False                                   True
# 4                  True                                  False
#
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check  Churn_Yes
# 0                            True                       False      False
# 1                           False                        True      False
# 2                           False                       False       True
# 3                           False                       False      False
# 4                            True                       False       True
#
# [5 rows x 24 columns]
